# %% [markdown]
# https://docs.google.com/spreadsheets/d/1MSsZAuj3emZPxujdPaz86s6bIrVSNpV6ZSOWKxEmk8E/edit#gid=0

# %% [markdown]
# ## 1. String

# %%
s = 'abcde'
type(s)
# Out:
# str

# %%
s[1]
# Out:
# 'b'

# %%
s[1:3]
# Out:
# 'bc'

# %%
s.find('f')
# Out:
# -1

# %%
s.find('c')
# Out:
# 2

# %%
s.index('f')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/5p/l3b0fr1x5wn7450vgnp88r080000gn/T/ipykernel_1239/1425875407.py in <module>
# ----> 1 s.index('f')
#
# ValueError: substring not found

# %%
s1 = 'ababcda'
s1.count('ab')
# Out:
# 2

# %%
s2= '   abcde   '
s2.lstrip()
# Out:
# 'abcde   '

# %%
s2
# Out:
# '   abcde   '

# %%
s2.rstrip()
# Out:
# '   abcde'

# %%
s2.strip()
# Out:
# 'abcde'

# %%
print(s.replace('a','y'))
s
# Out:
# ybcde
# 'abcde'

# %%
s.split(' ')
# Out:
# ['abcde']

# %%
s3 = 'ab cd e'
s3.split(' ')
# Out:
# ['ab', 'cd', 'e']

# %%
print(s3)
# Out:
# ab cd e

# %%
s1.endswith('')
# Out:
# False
